# %%
osoba = {
"user" : {"prezime" : "popovic",
"godine": "19"},
"adresa" : {"ulica":"dorcol"}
}
print(osoba ["user"]["prezime"])
# Out:
# popovic

# %%
osoba = {
"user" : {"prezime" : "popovic",
"godine": "19"},
"adresa" : {"ulica":"dorcol"}
}
print(osoba ["user"]["prezime"], osoba["adresa"]["ulica"])
# Out:
# popovic dorcol

# %%
osoba = {
"user" : {"prezime" : "popovic",
"godine": "19"},
"adresa" : {"ulica":"dorcol"}
}
print(osoba["user"]["prezime"], osoba["user"]["godine"], osoba["adresa"]["ulica"])
# Out:
# popovic 19 dorcol

# %%
firma = {
    "direktor": {
        "ime": "Marko",
        "godine": 45
    },
    "zaposleni": {
        "ime": "Jovan",
        "godine": 30
    }
}

print(firma["direktor"]["ime"], firma["direktor"]["godine"], firma["zaposleni"]["ime"])
# Out:
# Marko 45 Jovan
