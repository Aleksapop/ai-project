# %%
lista = [1, 23, 45, 67]
lista.insert(1, 58)
print(lista)
# Out:
# [1, 58, 23, 45, 67]

# %%
lista = [1, 23, 45, 67]
lista.pop()
print(lista)
# Out:
# [1, 23, 45]

# %%
lista = [1, 23, 45, 67]
lista.pop(1)
print(lista)
# Out:
# [1, 45, 67]

# %%
lista = [1, 23, 45, 67]
lista.remove(67)
print(lista)
# Out:
# [1, 23, 45]

# %%
dupla_lista = [[1, 2, 3], [4, 5, 6], [7, 8, 9, 13]]
print(dupla_lista[0][1], dupla_lista[0][2], dupla_lista[1], dupla_lista[2][3])
# Out:
# 2 3 [4, 5, 6] 13
