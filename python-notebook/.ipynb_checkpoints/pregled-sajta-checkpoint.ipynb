# %%
# !pip uninstall -y nltk
# !pip install --upgrade nltk
# Out:
# Found existing installation: nltk 3.9.2
# Uninstalling nltk-3.9.2:
#   Successfully uninstalled nltk-3.9.2
# Collecting nltk
#   Downloading nltk-3.9.3-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: click in /opt/anaconda3/lib/python3.13/site-packages (from nltk) (8.2.1)
# Requirement already satisfied: joblib in /opt/anaconda3/lib/python3.13/site-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/anaconda3/lib/python3.13/site-packages (from nltk) (2025.9.1)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.13/site-packages (from nltk) (4.67.1)
# Downloading nltk-3.9.3-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 5.1 MB/s  0:00:00 eta 0:00:01
# Installing collected packages: nltk
# Successfully installed nltk-3.9.3

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /Users/aleksa/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# !pip install selenium webdriver-manager requests beautifulsoup4
# Out:
# Collecting selenium
#   Downloading selenium-4.41.0-py3-none-any.whl.metadata (7.5 kB)
# Collecting webdriver-manager
#   Downloading webdriver_manager-4.0.2-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.13/site-packages (2.32.5)
# Requirement already satisfied: beautifulsoup4 in /opt/anaconda3/lib/python3.13/site-packages (4.13.5)
# Collecting certifi>=2026.1.4 (from selenium)
#   Downloading certifi-2026.2.25-py3-none-any.whl.metadata (2.5 kB)
# Collecting trio<1.0,>=0.31.0 (from selenium)
#   Downloading trio-0.33.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting trio-websocket<1.0,>=0.12.2 (from selenium)
#   Downloading trio_websocket-0.12.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: typing_extensions<5.0,>=4.15.0 in /opt/anaconda3/lib/python3.13/site-packages (from selenium) (4.15.0)
# Collecting urllib3<3.0,>=2.6.3 (from urllib3[socks]<3.0,>=2.6.3->selenium)
#   Downloading urllib3-2.6.3-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: websocket-client<2.0,>=1.8.0 in /opt/anaconda3/lib/python3.13/site-packages (from selenium) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from trio<1.0,>=0.31.0->selenium) (25.4.0)
# Requirement already satisfied: sortedcontainers in /opt/anaconda3/lib/python3.13/site-packages (from trio<1.0,>=0.31.0->selenium) (2.4.0)
# Requirement already satisfied: idna in /opt/anaconda3/lib/python3.13/site-packages (from trio<1.0,>=0.31.0->selenium) (3.11)
# Collecting outcome (from trio<1.0,>=0.31.0->selenium)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: sniffio>=1.3.0 in /opt/anaconda3/lib/python3.13/site-packages (from trio<1.0,>=0.31.0->selenium) (1.3.0)
# Collecting wsproto>=0.14 (from trio-websocket<1.0,>=0.12.2->selenium)
#   Downloading wsproto-1.3.2-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /opt/anaconda3/lib/python3.13/site-packages (from urllib3[socks]<3.0,>=2.6.3->selenium) (1.7.1)
# Requirement already satisfied: python-dotenv in /opt/anaconda3/lib/python3.13/site-packages (from webdriver-manager) (1.1.0)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.13/site-packages (from webdriver-manager) (25.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/lib/python3.13/site-packages (from requests) (3.4.4)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/lib/python3.13/site-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: h11<1,>=0.16.0 in /opt/anaconda3/lib/python3.13/site-packages (from wsproto>=0.14->trio-websocket<1.0,>=0.12.2->selenium) (0.16.0)
# Downloading selenium-4.41.0-py3-none-any.whl (9.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 44.7 MB/s  0:00:00 eta 0:00:01
# Downloading trio-0.33.0-py3-none-any.whl (510 kB)
# Downloading trio_websocket-0.12.2-py3-none-any.whl (21 kB)
# Downloading urllib3-2.6.3-py3-none-any.whl (131 kB)
# Downloading webdriver_manager-4.0.2-py2.py3-none-any.whl (27 kB)
# Downloading certifi-2026.2.25-py3-none-any.whl (153 kB)
# Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Downloading wsproto-1.3.2-py3-none-any.whl (24 kB)
# Installing collected packages: wsproto, urllib3, outcome, certifi, trio, webdriver-manager, trio-websocket, selenium
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.5.0
#     Uninstalling urllib3-2.5.0:
#       Successfully uninstalled urllib3-2.5.0
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2025.11.12
#     Uninstalling certifi-2025.11.12:
#       Successfully uninstalled certifi-2025.11.12
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8/8 [selenium]7/8 [selenium]
# Successfully installed certifi-2026.2.25 outcome-1.3.0.post0 selenium-4.41.0 trio-0.33.0 trio-websocket-0.12.2 urllib3-2.6.3 webdriver-manager-4.0.2 wsproto-1.3.2

# %%
import requests
from bs4 import BeautifulSoup
import re
from collections import Counter

# %%
def get_website_content(url):
    headers = {"User-Agent": "Mozilla/5.0"}
    response = requests.get(url, headers=headers, timeout=10)
    response.raise_for_status()
    return response.text

# %%
def simple_sentence_split(text):
    return re.split(r'(?<=[.!?]) +', text)

# %%
def summarize_text(text, num_sentences=3):
    sentences = simple_sentence_split(text)
    if len(sentences) <= num_sentences:
        return " ".join(sentences)

    words = re.findall(r'\w+', text.lower())
    word_freq = Counter(words)

    sentence_scores = {}
    for sentence in sentences:
        for word in re.findall(r'\w+', sentence.lower()):
            sentence_scores[sentence] = sentence_scores.get(sentence, 0) + word_freq[word]

    top_sentences = sorted(sentence_scores, key=sentence_scores.get, reverse=True)[:num_sentences]
    return " ".join(top_sentences)

# %%
def find_cheapest_product(soup):
    products = []
    price_patterns = re.compile(r'(\d+[.,]?\d*)\s?(RSD|rsd|€|EUR|eur)')

    for tag in soup.find_all(string=price_patterns):
        match = price_patterns.search(tag)
        if match:
            try:
                price = float(match.group(1).replace(",", "."))
                product_name = tag.parent.get_text(strip=True)
                products.append((product_name, price))
            except:
                pass

    if not products:
        return None

    return min(products, key=lambda x: x[1])

# %%
def analyze_website(url):
    try:
        html = get_website_content(url)
        soup = BeautifulSoup(html, "html.parser")
        page_text = soup.get_text(separator=" ", strip=True)

        cheapest_product = find_cheapest_product(soup)

        if cheapest_product:
            print("🛒 Izgleda da je ovo web shop.")
            print(f"Najjeftiniji proizvod: {cheapest_product[0]}")
            print(f"Cena: {cheapest_product[1]}")
        else:
            print("📰 Ovo ne izgleda kao shop. Kratak rezime sajta:")
            print(summarize_text(page_text))

    except Exception as e:
        print("Greška:", e)

# pokretanje
url = input("Unesite link sajta: ")
analyze_website(url)
# Out:
# Unesite link sajta:  https://sr.wikipedia.org/sr-ec/%D0%9A%D1%80%D0%B8%D1%81%D1%82%D0%B8%D1%98%D0%B0%D0%BD%D0%BE_%D0%A0%D0%BE%D0%BD%D0%B0%D0%BB%D0%B4%D0%BE
# 📰 Ovo ne izgleda kao shop. Kratak rezime sajta:
# Роналдо 2015/16: Суарез 2016/17: Меси 2017/18: Меси 2018/19: Меси 2019/20: Имобиле 2020/21: Левандовски 2021/22: Левандовски 2022/23: Холанд 2023/24: Кејн 2024/25: Мбапе п р у ФИФА фудбалер године ФИФА фудбалер године 1991: Матеус 1992: Ван Бастен 1993: Бађо 1994: Ромарио 1995: Веа 1996: Роналдо 1997: Роналдо 1998: Зидан 1999: Ривалдо 2000: Зидан 2001: Фиго 2002: Роналдо 2003: Зидан 2004: Роналдињо 2005: Роналдињо 2006: Канаваро 2007: Кака 2008: Кристијано Роналдо 2009: Меси ФИФА Златна лопта 2010: Меси 2011: Меси 2012: Меси 2013: Кристијано Роналдо 2014: Кристијано Роналдо 2015: Меси Најбољи ФИФА фудбалер 2016: Кристијано Роналдо 2017: Кристијано Роналдо 2018: Модрић 2019: Меси 2020: Левандовски 2021: Левандовски 2022: Меси 2023: Меси 2024: Винисијус Жуниор Повезано: Златна лопта п р у Најбољи стрелци Купа европских шампиона и УЕФА Лиге шампиона Куп европских шампиона 1956 : Милутиновић 1957 : Вајолет 1958 : Ди Стефано 1959 : Фонтен 1960 : Пушкаш 1961 : Агуас 1962 : Ди Стефано & Пушкаш 1963 : Алтафини 1964 : Ковачевић , Пушкаш & Мацола 1965 : Еузебио & Торес 1966 : Еузебио & Алберт 1967 : Химст 1968 : Еузебио 1969 : Лоу 1970 : Џоунс 1971 : Антонидис 1972 : Такач , Дунаи & Макари 1973 : Милер 1974 : Милер 1975 : Милер & Маркаров 1976 : Хајнкес 1977 : Милер & Кућинота 1978 : Симонсен 1979 : Сулсер 1980 : Лерби 1981 : Румениге , Сунис & Макдермот 1982 : Хенес 1983 : Роси 1984 : Сокол 1985 : Платини & Нилсон 1986 : Нилсон 1987 : Цветковић 1988 : Хађи , Маџер , Ферери, Мекојст, Новак, Мичел & Агуас 1989 : Ван Бастен 1990 : Ромарио & Папен 1991 : Папен & Пакулт 1992 : Папен & Јуран Лига шампиона 1993 : Ромарио 1994 : Куман & Руфер 1995 : Веа 1996 : Литманен 1997 : Пантић 1998 : Дел Пјеро 1999 : Шевченко & Јорк 2000 : Ривалдо , Раул & Жардел 2001 : Раул 2002 : Ван Нистелрој 2003 : Ван Нистелрој 2004 : Моријентес 2005 : Ван Нистелрој 2006 : Шевченко 2007 : Кака 2008 : Роналдо 2009 : Меси 2010 : Меси 2011 : Меси 2012 : Меси 2013 : Роналдо 2014 : Роналдо 2015 : Меси , Нејмар & Роналдо 2016 : Роналдо 2017 : Роналдо 2018 : Роналдо 2019 : Меси 2020 : Левандовски 2021 : Холанд 2022 : Бензема 2023 : Холанд 2024 : Кејн & Мбапе 2025 : Гираси & Рафиња п р у Најбољи стрелци Премијер лиге 1993: Шерингам 1994: Кол 1995: Ширер 1996: Ширер 1997: Ширер 1998: Даблин , Овен и Сатон 1999: Хаселбајнк , Овен и Јорк 2000: Филипс 2001: Хаселбајнк 2002: Анри 2003: Ван Нистелрој 2004: Анри 2005: Анри 2006: Анри 2007: Дрогба 2008: Роналдо 2009: Анелка 2010: Дрогба 2011: Бербатов и Тевез 2012: Ван Перси 2013: Ван Перси 2014: Суарез 2015: Агверо 2016: Кејн 2017: Кејн 2018: Салах 2019: Обамејанг , Мане и Салах 2020: Варди 2021: Кејн 2022: Салах и Сон 2023: Холанд 2024: Холанд 2025: Салах п р у Најбољи стрелци италијанске Серије А 1924: Шенфелд 1925: Мањоци 1926: Хирцер 1927: Поволни 1928: Либонати 1929: Росети 1930: Меаца 1931: Фолк 1932: Петроне / Скјавио 1933: Борел 1934: Борел 1935: Гуаита 1936: Меаца 1937: Пјола 1938: Меаца 1939: Бофи / Пуричели 1940: Бофи 1941: Пуричели 1942: Бофи 1943: Пјола 1946: Кастиљано 1947: В. Званични веб-сајт различит на Википодацима и Википедији Чланци са спољашњим везама на језику — енглески Шаблон:Twitter Шаблон:Twitter/ID/различит од Википодатака Чланци са FAST идентификаторима Чланци са ISNI идентификаторима Чланци са VIAF идентификаторима Чланци са WorldCat Entities идентификаторима Чланци са BIBSYS идентификаторима Чланци са BNE идентификаторима Чланци са BNF идентификаторима Чланци са BNFdata идентификаторима Чланци са CANTICN идентификаторима Чланци са GND идентификаторима Чланци са ICCU идентификаторима Чланци са J9U идентификаторима Чланци са LCCN идентификаторима Чланци са Libris идентификаторима Чланци са LNB идентификаторима Чланци са NCL идентификаторима Чланци са NDL идентификаторима Чланци са NKC идентификаторима Чланци са NLG идентификаторима Чланци са NLK идентификаторима Чланци са NTA идентификаторима Чланци са PLWABN идентификаторима Чланци са PortugalA идентификаторима Чланци са RSL идентификаторима Чланци са  ...
