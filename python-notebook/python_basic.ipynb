# %%
test = [2, [4, 11, "slavko", {"info": {"grad": "beograd", "godina": 2025}}], {"prezime": "popovic", 'grad': 'beograd', 'godina': 2025, 'adresa': 'ulica'},  37, ["adresa", "petar", "petroivc"]]
test[1][3]["info"]["adresa"] = "ulica"
print(test[2])
# Out:
# {'prezime': 'popovic', 'grad': 'beograd', 'godina': 2025, 'adresa': 'ulica'}

# %%
print(test[2]["prezime"])

for item in test[2]:
    print(item + "," , test[2][item])
# Out:
# popovic
# prezime, popovic
# grad, beograd
# godina, 2025
# adresa, ulica

# %%
objekat = [
    7,
    ["ime", "ana", "marko", ["podaci", {"telefon": "0641234567", "email": "ana@mail.com"}]],
    {
        "osoba1": {
            "ime": "Jovan",
            "prezime": "Petrovic",
            "adresa": {
                "ulica": "Bulevar Kralja Aleksandra",
                "grad": "Beograd",
                "postanski_broj": 11000
            },
            "godina": 1990,
            "hobiji": ["fudbal", "programiranje", {"sport": "kosarka", "intenzitet": "srednji"}]
        },
        "osoba2": {
            "ime": "Maja",
            "prezime": "Nikolic",
            "grad": "Novi Sad",
            "godina": 1995,
            "kontakt": {
                "telefon": "0659876543",
                "email": "maja@example.com"
            },
            "hobiji": ["muzika", "slikanje", ["planinarenje", "kampovanje"]]
        }
    },
    42,
    ["lista", 1, 2, 3, {"dodatno": ["x", "y", {"z": 99}]}],
    {
        "firma": {
            "naziv": "Tech Solutions",
            "lokacija": {
                "grad": "Beograd",
                "ulica": "Nemanjina 12"
            },
            "zaposleni": [
                {"ime": "Petar", "pozicija": "developer", "godina_rodjenja": 1992},
                {"ime": "Ivana", "pozicija": "designer", "godina_rodjenja": 1994}
            ]
        }
    },
    ["kraj", {"napomena": "ovo je kraj niza"}]
]
for index, item in enumerate(objekat):
    print(index, ":", item)
# Out:
# 0 : 7
# 1 : ['ime', 'ana', 'marko', ['podaci', {'telefon': '0641234567', 'email': 'ana@mail.com'}]]
# 2 : {'osoba1': {'ime': 'Jovan', 'prezime': 'Petrovic', 'adresa': {'ulica': 'Bulevar Kralja Aleksandra', 'grad': 'Beograd', 'postanski_broj': 11000}, 'godina': 1990, 'hobiji': ['fudbal', 'programiranje', {'sport': 'kosarka', 'intenzitet': 'srednji'}]}, 'osoba2': {'ime': 'Maja', 'prezime': 'Nikolic', 'grad': 'Novi Sad', 'godina': 1995, 'kontakt': {'telefon': '0659876543', 'email': 'maja@example.com'}, 'hobiji': ['muzika', 'slikanje', ['planinarenje', 'kampovanje']]}}
# 3 : 42
# 4 : ['lista', 1, 2, 3, {'dodatno': ['x', 'y', {'z': 99}]}]
# 5 : {'firma': {'naziv': 'Tech Solutions', 'lokacija': {'grad': 'Beograd', 'ulica': 'Nemanjina 12'}, 'zaposleni': [{'ime': 'Petar', 'pozicija': 'developer', 'godina_rodjenja': 1992}, {'ime': 'Ivana', 'pozicija': 'designer', 'godina_rodjenja': 1994}]}}
# 6 : ['kraj', {'napomena': 'ovo je kraj niza'}]

# %%
dodaj = []

for item in objekat[5]["firma"]["zaposleni"][0]:
    dodaj.append(item)
    dodaj.append(objekat[5]["firma"]["zaposleni"][0][item])

objekat[5]["firma"]["info"] = dodaj
objekat[5]["firma"]["zaposleni"][1]["info"] = {"adresa": "beograd", "grad": "ulcinj"}
print(objekat[5]["firma"]["zaposleni"])
# Out:
# [{'ime': 'Petar', 'pozicija': 'developer', 'godina_rodjenja': 1992}, {'ime': 'Ivana', 'pozicija': 'designer', 'godina_rodjenja': 1994, 'info': {'adresa': 'beograd', 'grad': 'ulcinj'}}]

# %%
zaradio = 90 
zaradio_lista = []
#napravi for lup koji ce da printa od 1 do 50, ali na 50 broju da doda 90

for i in range(1,51):
    if i == 50:
       i = zaradio + i
    zaradio_lista.append(i)
    if i == 17:
       a = i - zaradio
       zaradio_lista.append(a)

#napravi listu od celog ovog areja 
    
nova_lista = [{'ime': 'Petar', 'pozicija': 'developer', 'godina_rodjenja': 1992}, {'ime': 'Ivana', 'pozicija': 'designer', 'godina_rodjenja': 1994, 'info': {'adresa': 'beograd', 'grad': 'ulcinj'}}]
n = []
for index, item in enumerate(nova_lista):
    for item in nova_lista[index]:
        n.append(nova_lista[index][item])
        n.append(item)
print(n)
# Out:
# ['Petar', 'ime', 'developer', 'pozicija', 1992, 'godina_rodjenja', 'Ivana', 'ime', 'designer', 'pozicija', 1994, 'godina_rodjenja', {'adresa': 'beograd', 'grad': 'ulcinj'}, 'info']

# %%
zaradio = 500
date = 03142026
test = []
