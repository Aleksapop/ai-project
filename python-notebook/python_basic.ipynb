# %%
company = {
    "name": "PrototypeNext",
    "founded": 2025,
    "location": {
        "country": "USA",
        "state": "Florida",
        "cities": ["Miami", "Boca Raton"]
    },
    "teams": [
        {
            "team_name": "AI Engineering",
            "lead": {
                "name": "Alex",
                "experience_years": 8
            },
            "members": [
                {
                    "name": "John",
                    "skills": ["Python", "Machine Learning", "TensorFlow"],
                    "projects": [
                        {
                            "project_name": "AI Assistant",
                            "status": "active",
                            "technologies": ["Python", "FastAPI", "OpenAI"],
                            "tasks": [
                                {"task": "p-Design API", "completed": True},
                                {"task": "Train model", "completed": False}
                            ]
                        },
                        {
                            "project_name": "Data Analyzer",
                            "status": "planning",
                            "technologies": ["Pandas", "NumPy"],
                            "tasks": [
                                {"task": "Collect dataset", "completed": False},
                                {"task": "Build pipeline", "completed": False}
                            ]
                        }
                    ]
                },
                {
                    "name": "Maria",
                    "skills": ["Python", "NLP"],
                    "projects": [
                        {
                            "project_name": "Chatbot",
                            "status": "active",
                            "technologies": ["Python", "LangChain"],
                            "tasks": [
                                {"task": "Intent detection", "completed": True},
                                {"task": "Conversation flow", "completed": False}
                            ]
                        }
                    ]
                }
            ]
        },
        {
            "team_name": "Frontend",
            "lead": {
                "name": "David",
                "experience_years": 10
            },
            "members": [
                {
                    "name": "Sophia",
                    "skills": ["p-React", "p-TypeScript", "p-Next.js"],
                    "projects": [
                        {
                            "project_name": "Dashboard",
                            "status": "active",
                            "technologies": ["p-React", "p-Tailwind"],
                            "tasks": [
                                {"task": "Build layout", "completed": True},
                                {"task": "Integrate API", "completed": False}
                            ]
                        }
                    ]
                }
            ]
        }
    ]
}

# %%
company["teams"][0]["members"][0]["projects"][0]["tasks"][0]["task"]
# Out:
# 'p-Design API'

# %%
for item in company["teams"][1]["members"][0]["skills"]:
    print(item)
# Out:
# p-React
# p-TypeScript
# p-Next.js

# %%
company["teams"][1]["members"][0]["skills"]
# Out:
# ['p-React', 'p-TypeScript', 'p-Next.js']
