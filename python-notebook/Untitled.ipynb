# %%
#dobijam neki str ili listu i ja treba da vratim to bez uzastupnih duplikata npr "aaaabbbccca" = abca 
duplikati = "AAAABBBCCDAABBB"
#treba mi lista koja ce da cuva vrednost koju vracam
lista = []
#treba mi neki for lup koji ce da prodje kroz sve elemente
for item in duplikati:
    lista.append(item)

nova_lista = []
for i, item in enumerate(lista):
    traker = i + 1
    
    nova_lista = []
for i, item in enumerate(lista):
    traker = i + 1
    if traker < len(lista) and item != lista[traker]:
        nova_lista.append(item)
    elif traker == len(lista) and item != lista:
        nova_lista.append(item)
                
print(nova_lista)
#treba mi onda kod koji ce da uzme prvo slovo ispise i onda da preskoci ostala slova ili elemente dok ne dodje do prvog koji je drugaciji
# Out:
# ['A', 'B', 'C', 'D', 'A', 'B']
