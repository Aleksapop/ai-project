# %%
test = [2, [4, 11, "slavko", {"info": {"grad": "beograd", "godina": 2025}}], {"prezime": "popovic"}, 37, ["adresa", "petar", "petroivc"]]
test[1][3]["info"]["adresa"] = "ulica"
print(test)
# Out:
# [2, [4, 11, 'slavko', {'info': {'grad': 'beograd', 'godina': 2025, 'adresa': 'ulica'}}], {'prezime': 'popovic'}, 37, ['adresa', 'petar', 'petroivc']]

# %%
nova_lista = []

for value in test[1][3]["info"].values():
    nova_lista.append(value)

print(nova_lista)
# Out:
# ['beograd', 2025, 'ulica']
